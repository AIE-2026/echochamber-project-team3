# %% [markdown]
# # C5.01 Corpus agenti - Tema 2
#
#
# Scop: ne uităm la `data/corpus_typed.json`, verificăm distribuția bulelor și alegem ce exemple merită păstrate pentru vector store.

# %% [markdown]
# ## 1. Setup

# %%
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().parents[1]
DATA_PATH = PROJECT_ROOT / "data" / "typed" / "corpus_typed.jsonl"

print("PROJECT_ROOT:", PROJECT_ROOT)
print("DATA_PATH:", DATA_PATH)
print("Există?", DATA_PATH.exists())
# Out:
# PROJECT_ROOT: c:\Users\valer\Desktop\Analiza Datelor Complexe\17. AI Avansat\echochamber-project-team3
# DATA_PATH: c:\Users\valer\Desktop\Analiza Datelor Complexe\17. AI Avansat\echochamber-project-team3\data\typed\corpus_typed.jsonl
# Există? True

# %%
DATA_PATH
# Out:
# WindowsPath('c:/Users/valer/Desktop/Analiza Datelor Complexe/17. AI Avansat/echochamber-project-team3/data/typed/corpus_typed.jsonl')

# %% [markdown]
# ## 2. Încărcăm corpusul

# %%
df = pd.read_json(DATA_PATH, lines=True)
df.head(2)
# Out:
#                                           id       source_channel  \
# 0  yt_iH8jB4NlV9Y_UgxGvCWbzsvB3I-nSy54AaABAg  georgesimionoficial
# 1  yt_iH8jB4NlV9Y_UgwiYbOpe89FfXbeIpl4AaABAg  georgesimionoficial
#
#   channel_family                                        video_title  \
# 0  sovereigntist  Episodul 2: Cum ne-au furat alegerile - Turism...
# 1  sovereigntist  Episodul 2: Cum ne-au furat alegerile - Turism...
#
#                                                 text  low_information  \
# 0  Metoda votului cetatenilor din Republica Moldo...            False
# 1  Doamne cu atâtea dovezi și nicio instituție in...            False
#
#    pre_filtered target_specific target_refined        target_l1  ...  \
# 0         False     nicusor_dan    nicusor_dan  Instituții stat  ...
# 1         False          simion         simion    Sovereigntist  ...
#
#   repr_pluralist_present repr_pluralist_strength dem_procedure_rejected  \
# 0                  False                       0                  False
# 1                  False                       0                  False
#
#    dem_procedure_defended  call_to_action_present  call_to_action_strength  \
# 0                   False                    True                        1
# 1                   False                   False                        0
#
#    confidence            discourse_type          discourse_subtype  \
# 0         0.9  T2_grievance_anti_sistem   grievance_conspiratorial
# 1         0.9     T1_suport_personalist  suport_afectiv_suveranist
#
#    type_confidence
# 0             high
# 1           medium
#
# [2 rows x 38 columns]

# %% [markdown]
# ## 3. Vedem structura datelor

# %%
len(df)
# Out:
# 17886

# %%
print("Coloane:")
df.columns
# Out:
# Coloane:
# Index(['id', 'source_channel', 'channel_family', 'video_title', 'text',
#        'low_information', 'pre_filtered', 'target_specific', 'target_refined',
#        'target_l1', 'target_l2', 'stance_to_target', 'primary_target_hint',
#        'target_confidence', 'inst_neg_present', 'inst_neg_strength',
#        'inst_pos_present', 'inst_pos_strength',
#        'epist_hidden_coordination_present',
#        'epist_hidden_coordination_strength',
#        'epist_evidence_verification_present',
#        'epist_evidence_verification_strength',
#        'geo_anti_external_domination_present',
#        'geo_anti_external_domination_strength',
#        'geo_pro_external_anchoring_present',
#        'geo_pro_external_anchoring_strength', 'repr_personalist_present',
#        'repr_personalist_strength', 'repr_pluralist_present',
#        'repr_pluralist_strength', 'dem_procedure_rejected',
#        'dem_procedure_defended', 'call_to_action_present',
#        'call_to_action_strength', 'confidence', 'discourse_type',
#        'discourse_subtype', 'type_confidence'],
#       dtype='object')

# %%
df["discourse_type"].value_counts(dropna=False)
# Out:
# discourse_type
# T2_grievance_anti_sistem      7583
# T1_suport_personalist         4624
# T6_afectiv_pozitional         3726
# T4_conspiratie_externalism    1506
# T3_opozitie_suveranista        261
# T5_pro_democratic_european     186
# Name: count, dtype: int64

# %%
## Exemplu de text pentru fiecare tip de discurs

# %%
for bubble in df["discourse_type"].value_counts().index:
    print("\n" + "="*80)
    print(bubble)
    print("="*80)
    
    sample = df[df["discourse_type"] == bubble]["text"].dropna().head(5)
    
    for i, text in enumerate(sample, 1):
        print(f"\n{i}. {text[:50]}")
# Out:
# ================================================================================
# T2_grievance_anti_sistem
# ================================================================================
#
# 1. Metoda votului cetatenilor din Republica Moldova a
#
# 2. Calin Georgescu si George Simion la puscarieeee!!
#
# 3. S-au furat prin liste suplimentare, într-un sat di
#
# 4. Eu nu cred că caracatița poate fi dată la parte !E
#
# 5. Știu ca există un sistem de vot electronic în care
#
# ================================================================================
# T1_suport_personalist
# ================================================================================
#
# 1. Doamne cu atâtea dovezi și nicio instituție intern
#
# 2. Noi oricum știm asta dar întrebarea mea este domnu
#
# 3. Felicitări și RESPECT George Simion! Nu te opri! V
#
# 4. Haideți in stradă pe 20 iulie!!!! Să dăm jos hoții
#
# 5. MILIOANE DE ROMÂNI DEMNI SUNTEM ALĂTURI DE TINE,GE
#
# ================================================================================
# T6_afectiv_pozitional
# ================================================================================
#
# 1. Adevarul sa fie facut prezent si rezultatul sa fie
#
# 2. Ceea ce face este demn de noi romanii adevarati .
#
# 3. Si de trebuie deposite de combustibil degeaba avem
#
# 4. Dumnezeu sa Binecuvinteze Partidul Aur, 🇹🇩🙏 Români
#
# 5. Felicitari pentru discurs! ❤️🙏🇷🇴 Si pentru consecv
#
# ================================================================================
# T4_conspiratie_externalism
# ================================================================================
#
# 1. Atunci daca aveți dovezi împotriva la Maya Sandu d
#
# 2. Dom-le am văzut cu ochii nostrii cum sa fraudat to
#
# 3. Domnule Simion, cine sunt oamenii acestia si in ce
#
# 4. George pina Mr Trump nu is baga mina nu aveti sans
#
# 5. 2:51 Caaaat? 10.000 Euro la 100.000 urmăritori? O
#
# ================================================================================
# T3_opozitie_suveranista
# ================================================================================
#
# 1. Să zicem că ar fi fost 500 de autocare prin absurd
#
# 2. Eu înteleg că mănânci căcat dar chiar nu ai nicio
#
# 3. deci dovezi lipsa, doar marturii inventate.. bravo
#
# 4. Puneti mana si mai cercetati, nu mai credeti toate
#
# 5. George dacă tu știi că te-au furat atunci nu trebu
#
# ================================================================================
# T5_pro_democratic_european
# ================================================================================
#
# 1. Este ilegal și extrem de riscant să încerci să vot
#
# 2. Nu ajută să vedem asta trebuie să folosiți datele
#
# 3. Mă voi realizați că votul s-a încheiat și Nicușor
#
# 4. PERSPECTIVA MEA E CLA 2:22 RA, E OPTIMA! VOTEZ NIC
#
# 5. PERSPECTIVA MEA E CLARA, E OPTIMA. VOTEZ NICUSOR D

# %% [markdown]
# # 4. Pastram doar 150 de bula

# %%
# Alegem un subset simplu pentru curs: maximum 150 texte per bulă

N_PER_BUBBLE = 150

df_sample = (
    df[df["discourse_type"].notna()]
    .sort_values("type_confidence", ascending=False)
    .groupby("discourse_type", group_keys=False)
    .head(N_PER_BUBBLE)
    .copy()
)

df_sample["discourse_type"].value_counts()
# Out:
# discourse_type
# T3_opozitie_suveranista       150
# T2_grievance_anti_sistem      150
# T1_suport_personalist         150
# T4_conspiratie_externalism    150
# T5_pro_democratic_european    150
# T6_afectiv_pozitional         150
# Name: count, dtype: int64

# %%
from pathlib import Path

OUT_PATH = Path.cwd() / "data" / "typed" / "corpus_c5_sample.jsonl"

OUT_PATH.parent.mkdir(parents=True, exist_ok=True)

df_sample.to_json(OUT_PATH, orient="records", lines=True, force_ascii=False)

print("Saved to:", OUT_PATH)
# Out:
# Saved to: c:\Users\valer\Desktop\Analiza Datelor Complexe\17. AI Avansat\echochamber-project-team3\notebooks\student_01\data\typed\corpus_c5_sample.jsonl

# %%
# Păstrăm doar coloanele utile și salvăm corpusul pentru etapa următoare

keep_cols = [
    "id", "text", "source_channel", "channel_family", "video_title",
    "target_refined", "stance_to_target",
    "confidence", "discourse_type", "discourse_subtype", "type_confidence"
]

df_sample = df_sample[keep_cols].drop_duplicates(subset="text").copy()

OUT_PATH = Path("data/typed/corpus_c5_sample.jsonl")
df_sample.to_json(OUT_PATH, orient="records", lines=True, force_ascii=False)

print(df_sample.shape)
print(OUT_PATH)
df_sample.head(2)
# Out:
# (896, 11)
# data\typed\corpus_c5_sample.jsonl
#                                               id  \
# 17885  yt_Tx8GhU2LeyI_UgwoWOyzF2UbPYnguUB4AaABAg
# 15394  yt_joXkZDqGZQU_Ugyqb1XZ7P8GTnJS_4p4AaABAg
#
#                                                     text     source_channel  \
# 17885  Am toată încrederea că oameni ( de bine ) ca :...  AlephNewsOfficial
# 15394  Semneaza Bo$$ ca la urmatoarele alegerii nu ma...       NicusorDanRO
#
#          channel_family                                        video_title  \
# 17885        mainstream  ATENȚIE: România e „binevenită” să aplice iar ...
# 15394  mainstream_actor  🟢 Declarații de presă comune cu Președintele U...
#
#       target_refined stance_to_target  confidence            discourse_type  \
# 17885         simion             anti         0.9   T3_opozitie_suveranista
# 15394    nicusor_dan             anti         0.9  T2_grievance_anti_sistem
#
#            discourse_subtype type_confidence
# 17885        opozitie_difuza          medium
# 15394  grievance_mobilizator          medium

# %% [markdown]
# ## 5. Exportul bulelor finale
# În această etapă transformăm corpusul tipologizat în fișiere separate, câte unul pentru fiecare bulă finală.
# Codurile `T1`, `T2`, `T3`, `T4`, `T5` vin din adnotare, dar în aplicație folosim numele finale ale agenților:
# | Agent | Personalitate | Cum vorbește | Ce îl definește |
# |---|---|---|---|
# | Personalist-salvator | devotat, admirativ, sigur | laudativ, emoțional, încrezător | vede liderul ca soluție excepțională |
# | Anti-sistem | furios, suspicios, dezamăgit | acuzator, moralizator, direct | vede instituțiile și „sistemul” ca profund compromise |
# | Anti-suveranist | critic, vigilent, defensiv | contestatar, mai argumentativ | respinge liderii și discursul suveranist |
# | Conspiraționist | alarmist, hiper-suspicios | speculativ, revelator, totalizant | explică evenimentele prin forțe ascunse și actori externi |
# | Pro-european | normativ, moderat, legalist | sobru, justificativ, procedural | apără regulile, instituțiile și ancorarea europeană |
# `T6_afectiv_pozitional` nu devine agent principal în C5. Rămâne categorie transversală / rezervă.

# %%
BUBBLES = {
    "T1_suport_personalist": {
        "agent": "Personalist-salvator",
        "slug": "personalist_salvator",
        "personality": "devotat, admirativ, sigur",
        "speaks": "laudativ, emoțional, încrezător",
        "definition": "vede liderul ca soluție excepțională",
    },
    "T2_grievance_anti_sistem": {
        "agent": "Anti-sistem",
        "slug": "anti_sistem",
        "personality": "furios, suspicios, dezamăgit",
        "speaks": "acuzator, moralizator, direct",
        "definition": "vede instituțiile și „sistemul” ca profund compromise",
    },
    "T3_opozitie_suveranista": {
        "agent": "Anti-suveranist",
        "slug": "anti_suveranist",
        "personality": "critic, vigilent, defensiv",
        "speaks": "contestatar, mai argumentativ",
        "definition": "respinge liderii și discursul suveranist",
    },
    "T4_conspiratie_externalism": {
        "agent": "Conspiraționist",
        "slug": "conspirationist",
        "personality": "alarmist, hiper-suspicios",
        "speaks": "speculativ, revelator, totalizant",
        "definition": "explică evenimentele prin forțe ascunse și actori externi",
    },
    "T5_pro_democratic_european": {
        "agent": "Pro-european",
        "slug": "pro_european",
        "personality": "normativ, moderat, legalist",
        "speaks": "sobru, justificativ, procedural",
        "definition": "apără regulile, instituțiile și ancorarea europeană",
    },
}

# %%
"""
OUT_DIR = Path("data/bubbles")
OUT_DIR.mkdir(parents=True, exist_ok=True)

N_PER_BUBBLE = 50

for old_type, meta in BUBBLES.items():
    bubble_df = (
        df_sample[df_sample["discourse_type"] == old_type]
        .drop_duplicates(subset="text")
        .head(N_PER_BUBBLE)
        .copy()
    )

    bubble_df["agent"] = meta["agent"]
    bubble_df["slug"] = meta["slug"]
    bubble_df["personality"] = meta["personality"]
    bubble_df["speaks"] = meta["speaks"]
    bubble_df["definition"] = meta["definition"]
    bubble_df["source_type"] = old_type

    out_path = OUT_DIR / f"{meta['slug']}.jsonl"
    bubble_df.to_json(out_path, orient="records", lines=True, force_ascii=False)

    print(f"{meta['agent']}: {len(bubble_df)} texte -> {out_path}")

"""
# Out:
# '\nOUT_DIR = Path("data/bubbles")\nOUT_DIR.mkdir(parents=True, exist_ok=True)\n\nN_PER_BUBBLE = 50\n\nfor old_type, meta in BUBBLES.items():\n    bubble_df = (\n        df_sample[df_sample["discourse_type"] == old_type]\n        .drop_duplicates(subset="text")\n        .head(N_PER_BUBBLE)\n        .copy()\n    )\n\n    bubble_df["agent"] = meta["agent"]\n    bubble_df["slug"] = meta["slug"]\n    bubble_df["personality"] = meta["personality"]\n    bubble_df["speaks"] = meta["speaks"]\n    bubble_df["definition"] = meta["definition"]\n    bubble_df["source_type"] = old_type\n\n    out_path = OUT_DIR / f"{meta[\'slug\']}.jsonl"\n    bubble_df.to_json(out_path, orient="records", lines=True, force_ascii=False)\n\n    print(f"{meta[\'agent\']}: {len(bubble_df)} texte -> {out_path}")\n\n'

# %% [markdown]
# ## 6. Alege agentul tău și verifică textele
# Fiecare membru al echipei lucrează pe un singur agent.
# Datele vin din `df_sample`, iar agentul este legat de eticheta tehnică `discourse_type`.
# Scopul este să alegi aproximativ 50 texte bune pentru agentul tău.

# %%
# Alegeți un agent și încărcați textele corespunzătoare pentru etapa următoare
AGENTS = {
    "Personalist-salvator": {
        "type": "T1_suport_personalist",
        "slug": "personalist_salvator",
        "personality": "devotat, admirativ, sigur",
        "speaks": "laudativ, emoțional, încrezător",
        "definition": "vede liderul ca soluție excepțională",
    },
    "Anti-sistem": {
        "type": "T2_grievance_anti_sistem",
        "slug": "anti_sistem",
        "personality": "furios, suspicios, dezamăgit",
        "speaks": "acuzator, moralizator, direct",
        "definition": "vede instituțiile și „sistemul” ca profund compromise",
    },
    "Anti-suveranist": {
        "type": "T3_opozitie_suveranista",
        "slug": "anti_suveranist",
        "personality": "critic, vigilent, defensiv",
        "speaks": "contestatar, mai argumentativ",
        "definition": "respinge liderii și discursul suveranist",
    },
    "Conspiraționist": {
        "type": "T4_conspiratie_externalism",
        "slug": "conspirationist",
        "personality": "alarmist, hiper-suspicios",
        "speaks": "speculativ, revelator, totalizant",
        "definition": "explică evenimentele prin forțe ascunse și actori externi",
    },
    "Pro-european": {
        "type": "T5_pro_democratic_european",
        "slug": "pro_european",
        "personality": "normativ, moderat, legalist",
        "speaks": "sobru, justificativ, procedural",
        "definition": "apără regulile, instituțiile și ancorarea europeană",
    },
}

MY_AGENT = "Personalist-salvator"  # Alegeți unul dintre agenți: "Personalist-salvator", "Anti-sistem", "Anti-suveranist", "Conspiraționist", "Pro-european"

meta = AGENTS[MY_AGENT]

my_df = (
    df_sample[df_sample["discourse_type"] == meta["type"]]
    .drop_duplicates(subset="text")
    .copy()
)

print("Agent:", MY_AGENT)
print("Tip discurs:", meta["type"])
print("Texte disponibile:", len(my_df))

my_df[["id", "type_confidence", "discourse_subtype", "text"]].head(2)
# Out:
# Agent: Personalist-salvator
# Tip discurs: T1_suport_personalist
# Texte disponibile: 150
#                                              id type_confidence  \
# 3134  yt_X3bwh1-9nUU_Ugxc3Zx_bRhxFU18gXp4AaABAg          medium
# 3156  yt_bee6nXyzJ_E_UgyPoZoAIURM885eTr94AaABAg          medium
#
#               discourse_subtype  \
# 3134  suport_afectiv_suveranist
# 3156  suport_afectiv_suveranist
#
#                                                    text
# 3134  Ne au distrus hoții 😢,,,nu ne mai aparține nim...
# 3156  Era si timpul sa treceti la atac, prea multa d...

# %% [markdown]
# ### Cum verifici textele
# Citește textele afișate mai jos.
# Dacă un text este slab, copiază ID-ul lui în lista `REMOVE_IDS`.
# Elimină texte prea scurte, duplicate, ambigue sau care nu exprimă clar vocea agentului.|
#
# - pot sa folosesc un notepad pentru IDs
# daca nu gasesti 50 de comentarii bune, incarca mai multe.
# - poti folosi si alte metode (export text, csv) pentru vizualizarea si alegerea comentariilor

# %%
for _, row in my_df.head(70).iterrows():
    print("=" * 80)
    print("ID:", row["id"])
    print("Confidence:", row["type_confidence"])
    print("Subtype:", row["discourse_subtype"])
    print(row["text"][:700])
# Out:
# ================================================================================
# ID: yt_X3bwh1-9nUU_Ugxc3Zx_bRhxFU18gXp4AaABAg
# Confidence: medium
# Subtype: suport_afectiv_suveranist
# Ne au distrus hoții 😢,,,nu ne mai aparține nimic,,,, și au pus labele spurcate pe o țară in 89,,,,,,cu datorie externă 0,,,,,,,.
# ================================================================================
# ID: yt_bee6nXyzJ_E_UgyPoZoAIURM885eTr94AaABAg
# Confidence: medium
# Subtype: suport_afectiv_suveranist
# Era si timpul sa treceti la atac, prea multa defensiva pana acum si au profitat, respect
# ================================================================================
# ID: yt_bee6nXyzJ_E_UgzmsNNAxtBIZ34dyMB4AaABAg
# Confidence: medium
# Subtype: suport_afectiv_suveranist
# Vă mulțumim și noi și copii noștri care lucrează în nenorocita de Europă
# ================================================================================
# ID: yt_bee6nXyzJ_E_UgzdyYPCNenomSY1CGN4AaABAg
# Confidence: medium
# Subtype: suport_afectiv_suveranist
# 1:35 NOI știm că Sistemul ÎL hărțuiește mișelește că așa sunt ei dar vor platii curând ❤
# ================================================================================
# ID: yt_bee6nXyzJ_E_UgwsuxSiNBqVBBSlPt14AaABAg
# Confidence: medium
# Subtype: suport_afectiv_suveranist
# Ideea că poporul are dreptul sau chiar datoria de a înlătura un guvern care nu rezonează cu voința sa sau care acționează împotriva intereselor comune este un principiu fundamental al filozofiei politice și democratice. Cea ce traim din data de 6 dec 2024 nu se mai numeste democratie....În concluzie, conform principiilor democratice, guvernele trebuie să fie transparente, responsabile și receptive la nevoile populației. Dacă guvernul eșuează în a reprezenta poporul, cetățenii au dreptul la rezistență, prioritar prin mijloace democratice și pașnice. Personal nu stiu cat de mult o sa mai rezistam prin mijloace pasnice de a protesta, plus de alta cum se face ca parlamentarii sa beneficieze de i
# ================================================================================
# ID: yt_bnbjgKIS5Dw_UgyOLOV4TP5RMEOLJnV4AaABAg
# Confidence: medium
# Subtype: suport_afectiv_suveranist
# Multumim doamna ! Nu ca le pasa popilor dar macar a-ti spus-o ! Sant tot mai multi acesti indivizi in toate cultele, paradoxul e ca societatea e tot mai bolnava din punct de vedere moral cu criminali mai multi hoti de asemenea iar de mincinosi nu mai vorbim !!
# ================================================================================
# ID: yt_bnbjgKIS5Dw_Ugwf3ZMe2Ux_nf4WZl54AaABAg
# Confidence: medium
# Subtype: suport_afectiv_suveranist
# Așa este un mare adevăr grăiți D-zeu sa le răsplătească după cum fac i-au bănuții orfanului și văduvei și nu le pasa că ei nu au ce mânca .
# ================================================================================
# ID: yt_coeP4ouSxV8_Ugx3ISWMG1hMQfbUR0F4AaABAg
# Confidence: medium
# Subtype: suport_afectiv_suveranist
# Ce bataie de joc, inumam ce fac acesti tradatori! Credinta si increderea in Dumnezeu sa va sprijine familia ! Doamne ajuta sa iasa adevarul la iveala!❤
# ================================================================================
# ID: yt_pO0JOPX1I7Q_UgzHJ11AsH-CiJ0fhzB4AaABAg
# Confidence: medium
# Subtype: suport_afectiv_suveranist
#
# ================================================================================
# ID: yt_bnbjgKIS5Dw_UgyMZmdeWLgHhRMPmFJ4AaABAg
# Confidence: medium
# Subtype: suport_afectiv_suveranist
# Bravo Diana dar dacă nu plătești taxa anuala nu te înmormântează 😢. așa am ajuns 😢eu mă rog acasă.😢
# ================================================================================
# ID: yt_bnbjgKIS5Dw_Ugz1O2prITOnSyFl4yR4AaABAg
# Confidence: medium
# Subtype: suport_afectiv_suveranist
# 👍💯👏👏👏👏👏👏👏💯. Foarte Bine Spus Punctat și Realist. Hoți, Farisei,Demagogi, Ipocriți, Trădători și Inumani. Foarte puțini sunt între ei, care într-adevăr ajută/ sustin oamenii și copiii necăjiți .Respect doamna Diana.
# ================================================================================
# ID: yt_stxoPQZOAMU_Ugw_E6ymD7tUK3_l6WZ4AaABAg
# Confidence: medium
# Subtype: suport_afectiv_suveranist
# George ,te rog ai grijă la Mihail Neamțu .Nu e de-al nostru.
# ================================================================================
# ID: yt_stxoPQZOAMU_Ugz4GnDbBBs59SsiGet4AaABAg
# Confidence: medium
# Subtype: suport_afectiv_suveranist
# asta-i Romania reala stimati candidati la prezidentiale!asa se face o campanie electorala sincera si vie,in mijlocul oamenilor,la firul ierbii,nu in dezbateri unde va balacariti ca țațele! bravo Simion!
# ================================================================================
# ID: yt_bnbjgKIS5Dw_UgzDfagLSURsD_GjvyB4AaABAg
# Confidence: medium
# Subtype: suport_afectiv_suveranist
# Sectarilor nu mai mințiți degeaba. Doamne Diana este cetatean român creștin ortodox. Nici de cum nu ar vorbi așa ceva. Nu mai folositi imaginea dansei pentru denigrarea ortodoxiei.Nu mai spuneti minciuni ticalosilor!i
# ================================================================================
# ID: yt_bnbjgKIS5Dw_UgyWiVaOuVaGwEqaa4l4AaABAg
# Confidence: medium
# Subtype: suport_afectiv_suveranist
# La popi, credința sunt banii. Lor, popilor, le plac dolarii. Pe dolari scrie: credem în dumnezeu. Din cauza asta adoră dolarii, că sunt credința lor.
# ================================================================================
# ID: yt_R-wmsuFxku4_UgzNWM6zA8lKb8AiJhR4AaABAg
# Confidence: medium
# Subtype: suport_afectiv_suveranist
# Doamne ajuta ! Oricum ADEVARUL A IESIT LA IVEALA ,PRIN RAPORTUL FACUT DE AMERICANI .... DUSMANII NOSTRII SANT BRUXELUL , EU. /CLASA POLITICA ./
# ================================================================================
# ID: yt_WB_bGPi4oK4_UgyVovF4z-dTQGsfZLJ4AaABAg
# Confidence: medium
# Subtype: suport_afectiv_suveranist
# Ni se transmite un mesaj deosebit-Nu trebuie să ne certăm cu cei care nu văd realitatea, pe rețelele sociale și nici să facem pe detectivii, pentru că lucrurile sunt clare! Trebuie fiecare dintre noi să răspundem cu fapte bune și să fim modele de comportament pentru ceilalți care, încă, nu s-au trezit!🇷🇴🇷🇴🇷🇴
# ================================================================================
# ID: yt_WB_bGPi4oK4_UgxRQF3ga2sk8Jt7LwN4AaABAg
# Confidence: medium
# Subtype: suport_afectiv_suveranist
# Ei cred că judecă un om, dar de fapt aprind scânteia mult așteptată. Suntem pregătiți…
# ================================================================================
# ID: yt_WB_bGPi4oK4_Ugy9E9AE-Oxl0uDqczh4AaABAg
# Confidence: medium
# Subtype: suport_afectiv_suveranist
# Este o problema de programare și dominare si mai puțin de morala!...🍎 Ne aneninta, ne mutileaza, ne înlocuiesc sufletele copiilor noștri și ne decimeaza,in tara și afara. Vor sa ne încarce cu faptele lor murdare din Spania și Venezuela, asta este cernerea. Dar universul știe adevărul!!!
# ================================================================================
# ID: yt_WB_bGPi4oK4_UgxRwsxBWC8l2zLnXOh4AaABAg
# Confidence: medium
# Subtype: suport_afectiv_suveranist
# din pacate "trezirea in constiinta" nu se face doar de la distanta stand pe margine. Dupa raportul SUA care incrimineaza clar pe cei care au furat alegerile, aceasta condamnare in stilul Ursula/UW va ramane fara reactie din partea unui popor dezbinat, in transa, incapabil sa inteleaga ce greseala enorma a facut la alegerile trucate de anul trecut. Inca sunt romani care cred ca cei care ne conduc acum sunt patriotii care vor binele tarii si cu astfel de orbi nu poti "vedea" adevarul
# ================================================================================
# ID: yt_WB_bGPi4oK4_UgzFVRCCvWGkjOajJ_h4AaABAg
# Confidence: medium
# Subtype: suport_afectiv_suveranist
# IN ROMANIA COMUNISMUL.ESTE NAM SCAPAT DE EII..ESITI IN STRADA DATI JOS COMUNISTII EII NUL VOR PE GEORGESCU 😊😢
# ================================================================================
# ID: yt_rG4DGen0GFw_UgxU4WPIItm4Tuk3sqJ4AaABAg
# Confidence: medium
# Subtype: suport_afectiv_suveranist
# Fiecare trebuie să răspundă pentru faptele lui, nu pentru fapte inventate!
# ================================================================================
# ID: yt_WB_bGPi4oK4_UgzA_H-9NwOIMLfh5094AaABAg
# Confidence: medium
# Subtype: suport_afectiv_suveranist
# CĂ NOI POPORUL DORMIM!TREZIȚI-VĂ ODATĂ CEI CARE MĂCAR TRĂIESC ÎN SĂRĂCIE...EU DA TRĂIESC ÎN SĂRĂCIE...😢😭😢😭😢😭
# ================================================================================
# ID: yt_WB_bGPi4oK4_UgyHXmLNCwfmxklWL_t4AaABAg
# Confidence: medium
# Subtype: suport_afectiv_suveranist
# POATE SCAPAM DE LEPRE SI JAVRE POLITICE ,,USR PNL,PSD,,GUNOAIE PERVERSE,,,MIE SCARBA DE TOTI ,,,
# ================================================================================
# ID: yt_wBTMhbcFAL0_UgzUhL8OXJ7AwbL9D6N4AaABAg
# Confidence: medium
# Subtype: suport_afectiv_suveranist
# Domnule Călin Georgescu, mesajul dumneavoastră spune exact ce simt milioane de români. Anularea alegerilor este o rană deschisă pentru democrație și o lovitură pentru speranța întoarcerii acasă. Adevărul nu poate fi ascuns la nesfârșit. Suntem aici, conștienți și pregătiți.
# ================================================================================
# ID: yt_wBTMhbcFAL0_UgzIjx84eMqcVilCwWJ4AaABAg
# Confidence: medium
# Subtype: suport_afectiv_suveranist
# SE POATE CUMPĂRA O CONȘTIINȚĂ 🤔NICIODATĂ ❗️❗️Noi poporul român NU NE VINDEM PE 2 ARGINȚI ❗️❗️Dar ei trădătorii ne-au vândut țara fără acordul NOSTRU ❗️
# ================================================================================
# ID: yt_SpJ_Obw2I5I_UgwVebM8Fm9kIFXwPF54AaABAg
# Confidence: medium
# Subtype: suport_afectiv_suveranist
# vrem agricultura şi pământul nostru , grânarul europei înapoi !
# ================================================================================
# ID: yt_Ip7E56J5Ma0_Ugx0hAsRQzkZfuLXTup4AaABAg
# Confidence: medium
# Subtype: suport_afectiv_suveranist
# Securistii ii dau sansa saptamana de saptamana lui CG sa se adreseze poporului roman! In tot raul si un bine!
# ================================================================================
# ID: yt_Ip7E56J5Ma0_UgxfOyfdcr3VG-DTl-t4AaABAg
# Confidence: medium
# Subtype: suport_afectiv_suveranist
# Doar o revoluție,ne mai poate salva de această șleată de hoții care conduc Romania. Respect domnule Preṣedinte!
# ================================================================================
# ID: yt_rG4DGen0GFw_Ugx7nWF1YB6EP1E75Gh4AaABAg
# Confidence: medium
# Subtype: suport_afectiv_suveranist
# Pe 27 Februarie se împlinește un an de când băieții sunt în șah-mat. Fiți pe fază la sfârșit de Martie!
# ================================================================================
# ID: yt_pO0JOPX1I7Q_Ugx2-Nc01pLQfGoBLfZ4AaABAg
# Confidence: medium
# Subtype: suport_afectiv_suveranist
# Daca iese Georgescu toți draci ăștia de la tv de la parlament de la judecătorie știu ei care ...poporul va cere că ei sa fie judecați an față poporului și apoi executați sau daca nu pușcărie pe viață ...din cauza asta le este frica ...și uni din ei știu ce-i așteaptă ..

# %%
# elimin textele slabe și păstrez 50

REMOVE_IDS = [
    # pune aici ID-urile textelor slabe
]

clean_df = (
    my_df[~my_df["id"].isin(REMOVE_IDS)]
    .head(50)
    .copy()
)

clean_df["agent"] = MY_AGENT
clean_df["slug"] = meta["slug"]
clean_df["personality"] = meta["personality"]
clean_df["speaks"] = meta["speaks"]
clean_df["definition"] = meta["definition"]

print("Texte finale:", len(clean_df))
clean_df[["id", "agent", "text"]].head()
# Out:
# Texte finale: 50
#                                              id                 agent  \
# 3134  yt_X3bwh1-9nUU_Ugxc3Zx_bRhxFU18gXp4AaABAg  Personalist-salvator
# 3156  yt_bee6nXyzJ_E_UgyPoZoAIURM885eTr94AaABAg  Personalist-salvator
# 3166  yt_bee6nXyzJ_E_UgzmsNNAxtBIZ34dyMB4AaABAg  Personalist-salvator
# 3172  yt_bee6nXyzJ_E_UgzdyYPCNenomSY1CGN4AaABAg  Personalist-salvator
# 3173  yt_bee6nXyzJ_E_UgwsuxSiNBqVBBSlPt14AaABAg  Personalist-salvator
#
#                                                    text
# 3134  Ne au distrus hoții 😢,,,nu ne mai aparține nim...
# 3156  Era si timpul sa treceti la atac, prea multa d...
# 3166  Vă mulțumim și noi și copii noștri care lucrea...
# 3172  1:35 NOI știm că Sistemul ÎL hărțuiește mișele...
# 3173  Ideea că poporul are dreptul sau chiar datoria...

# %% [markdown]
# ### Descrierea agentului tău
# Înainte să exporți bula curată, descrie în 5–7 rânduri ce fel de voce discursivă are agentul ales.
# Nu descrie o persoană reală. Descrie un tip de discurs observat în corpus.
# Răspunde la aceste întrebări:
# - Cum vede acest agent instituțiile, politica sau actorii publici?
# - Ce ton folosește cel mai des?
# - Ce tip de argumente sau acuzații apar frecvent?
# - Ce îl diferențiază de celelalte bule?
# - Ce ar trebui să păstreze un viitor agent AI ca să sune coerent cu această bulă?

# %% [markdown]
# Descriere:
# - Agentul „Personalist-salvator” vede liderul ca pe o figură excepțională, capabilă să salveze țara și să repare un sistem considerat corupt sau incapabil. Instituțiile sunt privite cu neîncredere, iar liderul este prezentat ca fiind mai apropiat de oameni decât clasa politică tradițională.
# - Tonul folosit este afectiv, admirativ și emoțional. Comentariile exprimă susținere puternică, loialitate și încredere în lider, uneori într-un mod foarte personal.
# - Apar frecvent idei despre „trezirea poporului”, nedreptăți făcute de sistem și nevoia unui conducător puternic care să spună adevărul și să apere oamenii simpli.
# - Discursul pune accent pe valori precum patriotismul, credința, onoarea și curajul. Liderul este descris ca fiind sincer, persecutat pe nedrept sau diferit de ceilalți politicieni.
# - Față de alte bule, această voce discursivă este mai puțin argumentativă și mai mult emoțională, bazată pe admirație și identificare personală cu liderul.
# - Un viitor agent AI care ar reproduce această bulă ar trebui să păstreze un ton cald, sigur și susținător, să vorbească despre lider într-un mod pozitiv și să exprime neîncredere față de instituțiile considerate corupte sau controlate politic.

# %%
OUT_DIR = Path("../../data/bubbles")
OUT_DIR.mkdir(parents=True, exist_ok=True)

out_path = OUT_DIR / f"{meta['slug']}.jsonl"

clean_df.to_json(out_path, orient="records", lines=True, force_ascii=False)

print("Salvat:", out_path.resolve())
# Out:
# Salvat: C:\Users\valer\Desktop\Analiza Datelor Complexe\17. AI Avansat\echochamber-project-team3\data\bubbles\personalist_salvator.jsonl
