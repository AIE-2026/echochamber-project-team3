# %% [markdown]
# # C3 — Colectare comentarii YouTube
# În acest notebook colectăm un eșantion  de comentarii publice de pe YouTube.
# Scopul nu este să obținem corpusul final mare, ci să înțelegem fluxul:
# sursă → API → comentarii brute → fișier JSONL.
# La final, fiecare student salvează propriul fișier în `data/raw/`.

# %% [markdown]
# ## 1. Ce trebuie să avem pregătit
# Avem nevoie de:
# - fișier `.env` în root-ul proiectului
# - cheia `YOUTUBE_API_KEY`
# - un handle de canal YouTube
# Exemplu în `.env`:
# ```text
# YOUTUBE_API_KEY=cheia_ta_aici

# %%
from pathlib import Path
import os
import json
import requests
from datetime import datetime
from dotenv import load_dotenv

# %% [markdown]
# ## 2. Încărcăm cheia API
# Notebook-ul caută fișierul `.env` în root-ul proiectului.
# Dacă cheia nu este găsită, colectarea nu poate porni.

# %%
ROOT = Path.cwd()
while not (ROOT / ".env").exists() and ROOT.parent != ROOT:
    ROOT = ROOT.parent
load_dotenv(ROOT / ".env")
API_KEY = os.getenv("YOUTUBE_API_KEY")
BASE_URL = "https://www.googleapis.com/youtube/v3"
print("Root proiect:", ROOT)
print("Cheie găsită:", API_KEY is not None)
# Out:
# Root proiect: c:\Users\valer\Desktop\Analiza Datelor Complexe\17. AI Avansat\echochamber-project-team3
# Cheie găsită: True

# %% [markdown]
# ## 3. Alegem canalul și numărul de videoclipuri
# Fiecare student schimbă `student_id` și `handle`.
# Pentru exercițiu folosim puține videoclipuri, ca să nu consumăm inutil cota API.

# %%
student_id = "student_01"
handle = "RecorderRomania"
max_videos = 7
max_comments_per_video = 100
output_file = ROOT / "data" / "raw" / f"{student_id}_youtube_raw.jsonl"
print(output_file)
# Out:
# c:\Users\valer\Desktop\Analiza Datelor Complexe\17. AI Avansat\echochamber-project-team3\data\raw\student_01_youtube_raw.jsonl

# %% [markdown]
# ## 4. Găsim canalul YouTube
#
# YouTube lucrează intern cu `channel_id`, nu direct cu numele canalului.
# De aceea, primul pas este să transformăm handle-ul în `channel_id`.

# %%
channel_response = requests.get(
    f"{BASE_URL}/channels",
    params={
        "part": "id",
        "forHandle": handle,
        "key": API_KEY
    }
)
channel_data = channel_response.json()
channel_data
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'pyoaBdIZrextEpwgy46dnYfu1rY',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'xREcAlHpeXzSly5kQ6w2X0U6NeA',
#    'id': 'UChDQ6nYN6XyRU-8IEgbym1g'}]}

# %%
channel_id = channel_data["items"][0]["id"]
channel_id
# Out:
# 'UChDQ6nYN6XyRU-8IEgbym1g'

# %% [markdown]
# ## 5. Luăm cele mai recente videoclipuri
# Acum cerem ultimele videoclipuri publicate de canal.
# Pentru curs folosim doar câteva videoclipuri.

# %%
videos_response = requests.get(
    f"{BASE_URL}/search",
    params={
        "part": "snippet",
        "channelId": channel_id,
        "type": "video",
        "order": "date",
        "maxResults": max_videos,
        "key": API_KEY
    }
)
videos_data = videos_response.json()
videos_data["items"][0]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': '4gQevB4uzztdGqyCCNv34JoPU1g',
#  'id': {'kind': 'youtube#video', 'videoId': 'TFSXVaF5HnM'},
#  'snippet': {'publishedAt': '2026-05-05T08:54:22Z',
#   'channelId': 'UChDQ6nYN6XyRU-8IEgbym1g',
#   'title': 'Cazul salina Praid. Dezastrul pentru care nu a plătit nimeni #shorts',
#   'description': 'A trecut un an de la inundațiile masive care au înghițit Salina Praid, una dintre cele mai mari mine de sare din România și ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/TFSXVaF5HnM/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/TFSXVaF5HnM/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/TFSXVaF5HnM/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Recorder',
#   'liveBroadcastContent': 'none',
#   'publishTime': '2026-05-05T08:54:22Z'}}

# %%
videos = []
for item in videos_data["items"]:
    videos.append({
        "video_id": item["id"]["videoId"],
        "video_title": item["snippet"]["title"],
        "video_date": item["snippet"]["publishedAt"][:10]
    })
videos
# Out:
# [{'video_id': 'TFSXVaF5HnM',
#   'video_title': 'Cazul salina Praid. Dezastrul pentru care nu a plătit nimeni #shorts',
#   'video_date': '2026-05-05'},
#  {'video_id': '_pA7OBgLor4',
#   'video_title': 'Cazul Praid: o catastrofă, zero vinovați',
#   'video_date': '2026-05-04'},
#  {'video_id': 'LfS035CPy8o',
#   'video_title': 'Susține Recorder gratuit #shorts',
#   'video_date': '2026-04-24'},
#  {'video_id': 'v0PhekWVNOA',
#   'video_title': 'Se clatinǎ Imperiul Orban? #shorts',
#   'video_date': '2026-04-09'},
#  {'video_id': 'A3ufVNC6FKg',
#   'video_title': 'EXPLICATIV RECORDER. Alegeri în Ungaria. Se clatină Imperiul Orban?',
#   'video_date': '2026-04-08'},
#  {'video_id': 'xPqAlqF8efM',
#   'video_title': 'INVESTIGAȚIE RECORDER. Și inundațiile au culoare politică',
#   'video_date': '2026-03-26'},
#  {'video_id': 'HDsCdSOtxO0',
#   'video_title': 'EXPLICATIV RECORDER. Cum s-au repliat liderii sistemului după documentarul „Justiție capturată”',
#   'video_date': '2026-03-11'}]

# %% [markdown]
# ## 6. Colectăm comentariile
# Pentru fiecare videoclip luăm comentariile publice ordonate după relevanță.
# În acest exercițiu nu folosim paginare, deci luăm maximum 100 comentarii per videoclip.

# %%
comments = []
for video in videos:
    print("Colectez:", video["video_title"][:80])
    comments_response = requests.get(
        f"{BASE_URL}/commentThreads",
        params={
            "part": "snippet",
            "videoId": video["video_id"],
            "maxResults": max_comments_per_video,
            "textFormat": "plainText",
            "order": "relevance",
            "key": API_KEY
        }
    )
    comments_data = comments_response.json()
    for comment_item in comments_data.get("items", []):
        snippet = comment_item["snippet"]["topLevelComment"]["snippet"]
        record = {
            "id": f"yt_{video['video_id']}_{comment_item['id']}",
            "source_platform": "youtube",
            "source_channel": handle,
            "text_raw": snippet["textDisplay"],
            "video_id": video["video_id"],
            "video_title": video["video_title"],
            "video_date": video["video_date"],
            "comment_date": snippet["publishedAt"][:10],
            "likes": snippet["likeCount"],
            "collected_at": datetime.utcnow().strftime("%Y-%m-%d")
        }
        comments.append(record)
len(comments)
# Out:
# Colectez: Cazul salina Praid. Dezastrul pentru care nu a plătit nimeni #shorts
# C:\Users\valer\AppData\Local\Temp\ipykernel_29084\3206550858.py:28: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "collected_at": datetime.utcnow().strftime("%Y-%m-%d")
# Colectez: Cazul Praid: o catastrofă, zero vinovați
# Colectez: Susține Recorder gratuit #shorts
# Colectez: Se clatinǎ Imperiul Orban? #shorts
# Colectez: EXPLICATIV RECORDER. Alegeri în Ungaria. Se clatină Imperiul Orban?
# Colectez: INVESTIGAȚIE RECORDER. Și inundațiile au culoare politică
# Colectez: EXPLICATIV RECORDER. Cum s-au repliat liderii sistemului după documentarul „Just
# 505

# %% [markdown]
# # Explorare si curatare

# %% [markdown]
# ## 7. Inspectăm primele comentarii
# Înainte să salvăm fișierul, verificăm dacă datele arată cum trebuie.

# %%
comments[:3]
# Out:
# [{'id': 'yt_TFSXVaF5HnM_UgyYJLi1yvDaaTKLh554AaABAg',
#   'source_platform': 'youtube',
#   'source_channel': 'RecorderRomania',
#   'text_raw': 'Sfat util pentru dobitocii care au votat 36 de ani cu PSD(fostul PCR) acum au opțiunea să voteze cu AUR(PSD2).',
#   'video_id': 'TFSXVaF5HnM',
#   'video_title': 'Cazul salina Praid. Dezastrul pentru care nu a plătit nimeni #shorts',
#   'video_date': '2026-05-05',
#   'comment_date': '2026-05-05',
#   'likes': 29,
#   'collected_at': '2026-05-15',
#   'text': 'Sfat util pentru dobitocii care au votat 36 de ani cu PSD(fostul PCR) acum au opțiunea să voteze cu AUR(PSD2).'},
#  {'id': 'yt_TFSXVaF5HnM_UgzVEynAARw_IYeieMt4AaABAg',
#   'source_platform': 'youtube',
#   'source_channel': 'RecorderRomania',
#   'text_raw': 'De ce nu plătesc "responsabilii" toate pagubele?!😢',
#   'video_id': 'TFSXVaF5HnM',
#   'video_title': 'Cazul salina Praid. Dezastrul pentru care nu a plătit nimeni #shorts',
#   'video_date': '2026-05-05',
#   'comment_date': '2026-05-05',
#   'likes': 8,
#   'collected_at': '2026-05-15',
#   'text': 'De ce nu plătesc "responsabilii" toate pagubele?!😢'},
#  {'id': 'yt_TFSXVaF5HnM_Ugx68PiuBVcvsrdkbiN4AaABAg',
#   'source_platform': 'youtube',
#   'source_channel': 'RecorderRomania',
#   'text_raw': 'Nenorociților , distrugeți o țară !!!\nDoamne , pedepsește i pe trădători !!',
#   'video_id': 'TFSXVaF5HnM',
#   'video_title': 'Cazul salina Praid. Dezastrul pentru care nu a plătit nimeni #shorts',
#   'video_date': '2026-05-05',
#   'comment_date': '2026-05-06',
#   'likes': 5,
#   'collected_at': '2026-05-15',
#   'text': 'Nenorociților , distrugeți o țară !!! Doamne , pedepsește i pe trădători !!'}]

# %%
comments[0].keys()
# Out:
# dict_keys(['id', 'source_platform', 'source_channel', 'text_raw', 'video_id', 'video_title', 'video_date', 'comment_date', 'likes', 'collected_at', 'text'])

# %% [markdown]
# ## 8. Curățare minimă a textului
# Acum pornim de la `text_raw` și construim o variantă curățată în câmpul `text`.
# Nu schimbăm sensul comentariului. Eliminăm doar zgomot simplu: linkuri, spații inutile, texte prea scurte și duplicate.

# %%
import re

def clean_text(text):
    text = re.sub(r"http\S+", "", text)      # elimină linkuri
    text = re.sub(r"\s+", " ", text)         # normalizează spațiile
    return text.strip()

# %% [markdown]
# ## 9. Aplicăm curățarea
# Pentru fiecare comentariu păstrăm textul original în `text_raw` și adăugăm textul curățat în `text`.

# %%
for comment in comments:
    comment["text"] = clean_text(comment["text_raw"])

comments[0]
# Out:
# {'id': 'yt_TFSXVaF5HnM_UgyYJLi1yvDaaTKLh554AaABAg',
#  'source_platform': 'youtube',
#  'source_channel': 'RecorderRomania',
#  'text_raw': 'Sfat util pentru dobitocii care au votat 36 de ani cu PSD(fostul PCR) acum au opțiunea să voteze cu AUR(PSD2).',
#  'video_id': 'TFSXVaF5HnM',
#  'video_title': 'Cazul salina Praid. Dezastrul pentru care nu a plătit nimeni #shorts',
#  'video_date': '2026-05-05',
#  'comment_date': '2026-05-05',
#  'likes': 29,
#  'collected_at': '2026-05-15',
#  'text': 'Sfat util pentru dobitocii care au votat 36 de ani cu PSD(fostul PCR) acum au opțiunea să voteze cu AUR(PSD2).'}

# %% [markdown]
# ## 10. Filtrăm comentariile prea scurte
# Pentru exercițiu păstrăm doar comentariile care au cel puțin 60 de caractere.
# Comentariile foarte scurte sunt greu de interpretat în analiza discursivă.

# %%
MIN_CHARS = 60

comments_clean = [
    comment for comment in comments
    if len(comment["text"]) >= MIN_CHARS
]

print("Comentarii brute:", len(comments))
print("Comentarii după filtrarea lungimii:", len(comments_clean))
# Out:
# Comentarii brute: 505
# Comentarii după filtrarea lungimii: 300

# %% [markdown]
# ## 11. Filtrăm textele cu prea puține litere
# Comentariile formate mai ales din emoji, simboluri sau caractere izolate produc zgomot.
# Păstrăm comentariile în care cel puțin 50% dintre caractere sunt litere.

# %%
MIN_ALPHA = 0.5

def alpha_ratio(text):
    if len(text) == 0:
        return 0
    letters = sum(char.isalpha() for char in text)
    return letters / len(text)

comments_clean = [
    comment for comment in comments_clean
    if alpha_ratio(comment["text"]) >= MIN_ALPHA
]

print("Comentarii după filtrarea literelor:", len(comments_clean))
# Out:
# Comentarii după filtrarea literelor: 300

# %% [markdown]
# ## 12. Eliminăm duplicatele
# Dacă același text apare de mai multe ori, îl păstrăm o singură dată.

# %%
seen_texts = set()
unique_comments = []

for comment in comments_clean:
    text = comment["text"].lower()
    if text not in seen_texts:
        unique_comments.append(comment)
        seen_texts.add(text)

comments_clean = unique_comments

print("Comentarii finale după deduplicare:", len(comments_clean))
# Out:
# Comentarii finale după deduplicare: 299

# %% [markdown]
# ## 14. Salvăm fișierul curățat
# Salvăm rezultatul în `data/cleaned/`.

# %%
clean_output_file = ROOT / "data" / "cleaned" / f"{student_id}_youtube_clean.jsonl"
clean_output_file.parent.mkdir(parents=True, exist_ok=True)

with clean_output_file.open("w", encoding="utf-8") as f:
    for comment in comments_clean:
        f.write(json.dumps(comment, ensure_ascii=False) + "\n")

print("Comentarii curate salvate:", len(comments_clean))
print("Fișier:", clean_output_file)
# Out:
# Comentarii curate salvate: 299
# Fișier: c:\Users\valer\Desktop\Analiza Datelor Complexe\17. AI Avansat\echochamber-project-team3\data\cleaned\student_01_youtube_clean.jsonl

# %% [markdown]
# # Functia de curatare

# %%
import re

def clean_comments(comments, min_chars=60, min_alpha=0.5):
    cleaned = []
    seen_texts = set()
    
    for comment in comments:
        # 1. Curățare text
        text = comment["text_raw"]
        text = re.sub(r"http\S+", "", text)
        text = re.sub(r"\s+", " ", text).strip()
        
        # 2. Filtru lungime
        if len(text) < min_chars:
            continue
        
        # 3. Filtru proporție litere
        letters = sum(char.isalpha() for char in text)
        alpha_ratio = letters / len(text) if len(text) > 0 else 0
        
        if alpha_ratio < min_alpha:
            continue
        
        # 4. Filtru duplicate
        text_key = text.lower()
        if text_key in seen_texts:
            continue
        
        seen_texts.add(text_key)
        
        # 5. Păstrăm comentariul și adăugăm textul curățat
        new_comment = comment.copy()
        new_comment["text"] = text
        new_comment["lang"] = "ro"
        cleaned.append(new_comment)
    
    return cleaned

# %%
comments_clean = clean_comments(
    comments,
    min_chars=60,
    min_alpha=0.5
)

print("Comentarii brute:", len(comments))
print("Comentarii curate:", len(comments_clean))
# Out:
# Comentarii brute: 505
# Comentarii curate: 299

# %%
for comment in comments_clean[:3]:
    print("RAW:", comment["text_raw"])
    print("CLEAN:", comment["text"])
    print("---")
# Out:
# RAW: Sfat util pentru dobitocii care au votat 36 de ani cu PSD(fostul PCR) acum au opțiunea să voteze cu AUR(PSD2).
# CLEAN: Sfat util pentru dobitocii care au votat 36 de ani cu PSD(fostul PCR) acum au opțiunea să voteze cu AUR(PSD2).
# ---
# RAW: Nenorociților , distrugeți o țară !!!
# Doamne , pedepsește i pe trădători !!
# CLEAN: Nenorociților , distrugeți o țară !!! Doamne , pedepsește i pe trădători !!
# ---
# RAW: Amuzant, mina este PA dar salariul celor din conducere merge inainte
# CLEAN: Amuzant, mina este PA dar salariul celor din conducere merge inainte
# ---

# %%
clean_output_file = ROOT / "data" / "cleaned" / f"{student_id}_youtube_clean.jsonl"
clean_output_file.parent.mkdir(parents=True, exist_ok=True)

with clean_output_file.open("w", encoding="utf-8") as f:
    for comment in comments_clean:
        f.write(json.dumps(comment, ensure_ascii=False) + "\n")

print("Fișier salvat:", clean_output_file)
print("Comentarii salvate:", len(comments_clean))
# Out:
# Fișier salvat: c:\Users\valer\Desktop\Analiza Datelor Complexe\17. AI Avansat\echochamber-project-team3\data\cleaned\student_01_youtube_clean.jsonl
# Comentarii salvate: 299

# %% [markdown]
# 15. Ce am obținut
# Am produs două fișiere:
# - `data/raw/student_XX_youtube_raw.jsonl` — comentarii brute
# - `data/cleaned/student_XX_youtube_clean.jsonl` — comentarii curățate
# Fișierul curățat va putea fi unit cu fișierele celorlalți membri ai echipei.
