# %% [markdown]
# # C3 — Colectare comentarii YouTube
# În acest notebook colectăm un eșantion  de comentarii publice de pe YouTube.
# Scopul nu este să obținem corpusul final mare, ci să înțelegem fluxul:
# sursă → API → comentarii brute → fișier JSONL.
# La final, fiecare student salvează propriul fișier în `data/raw/`.

# %% [markdown]
# ## 1. Ce trebuie să avem pregătit
# Avem nevoie de:
# - fișier `.env` în root-ul proiectului
# - cheia `YOUTUBE_API_KEY`
# - un handle de canal YouTube
# Exemplu în `.env`:
# ```text
# YOUTUBE_API_KEY=cheia_ta_aici

# %%
from pathlib import Path
import os
import json
import requests
from datetime import datetime
from dotenv import load_dotenv

# %% [markdown]
# ## 2. Încărcăm cheia API
# Notebook-ul caută fișierul `.env` în root-ul proiectului.
# Dacă cheia nu este găsită, colectarea nu poate porni.

# %%
ROOT = Path.cwd()
while not (ROOT / ".env").exists() and ROOT.parent != ROOT:
    ROOT = ROOT.parent
load_dotenv(ROOT / ".env")
API_KEY = os.getenv("YOUTUBE_API_KEY")
BASE_URL = "https://www.googleapis.com/youtube/v3"
print("Root proiect:", ROOT)
print("Cheie găsită:", API_KEY is not None)
# Out:
# Root proiect: c:\Users\diana\Desktop\18.Ingineria_AI\echochamber-project-team3
# Cheie găsită: True

# %% [markdown]
# ## 3. Alegem canalul și numărul de videoclipuri
# Fiecare student schimbă `student_id` și `handle`.
# Pentru exercițiu folosim puține videoclipuri, ca să nu consumăm inutil cota API.

# %%
student_id = "student_05"
handle = "g4media479"
max_videos = 10
max_comments_per_video = 10
output_file = ROOT / "data" / "raw" / f"{student_id}_youtube_raw.jsonl"
print(output_file)
# Out:
# c:\Users\diana\Desktop\18.Ingineria_AI\echochamber-project-team3\data\raw\student_05_youtube_raw.jsonl

# %% [markdown]
# ## 4. Găsim canalul YouTube
#
# YouTube lucrează intern cu `channel_id`, nu direct cu numele canalului.
# De aceea, primul pas este să transformăm handle-ul în `channel_id`.

# %%
channel_response = requests.get(
    f"{BASE_URL}/channels",
    params={
        "part": "id",
        "forHandle": handle,
        "key": API_KEY
    }
)
channel_data = channel_response.json()
channel_data
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'tpLkftRzrEZBwCeHNfmbhLmT7LQ',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'ldviC2NaLFeklno0ofMswISqo7s',
#    'id': 'UCy18ElVAyfTEVHC4HYAcj5g'}]}

# %%
channel_id = channel_data["items"][0]["id"]
channel_id
# Out:
# 'UCy18ElVAyfTEVHC4HYAcj5g'

# %% [markdown]
# ## 5. Luăm cele mai recente videoclipuri
# Acum cerem ultimele videoclipuri publicate de canal.
# Pentru curs folosim doar câteva videoclipuri.

# %%
videos_response = requests.get(
    f"{BASE_URL}/search",
    params={
        "part": "snippet",
        "channelId": channel_id,
        "type": "video",
        "order": "date",
        "maxResults": max_videos,
        "key": API_KEY
    }
)
videos_data = videos_response.json()
videos_data["items"][0]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': 'FLcfMWbbPEjGNHpUgoVWw5XHam0',
#  'id': {'kind': 'youtube#video', 'videoId': 'p8Mw2mAtrQo'},
#  'snippet': {'publishedAt': '2026-05-19T08:22:44Z',
#   'channelId': 'UCy18ElVAyfTEVHC4HYAcj5g',
#   'title': 'Investigăm persoane cu funcții mai înalte în statul român / Interviu Kovesi Episodul 2',
#   'description': 'Laura Codruța Kovesi a declarat într-un interviu-eveniment pentru G4Media.ro realizat de Dan Tăpălagă că Parchetul European ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/p8Mw2mAtrQo/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/p8Mw2mAtrQo/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/p8Mw2mAtrQo/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'G4 Media',
#   'liveBroadcastContent': 'none',
#   'publishTime': '2026-05-19T08:22:44Z'}}

# %%
videos = []
for item in videos_data["items"]:
    videos.append({
        "video_id": item["id"]["videoId"],
        "video_title": item["snippet"]["title"],
        "video_date": item["snippet"]["publishedAt"][:10]
    })
videos
# Out:
# [{'video_id': 'p8Mw2mAtrQo',
#   'video_title': 'Investigăm persoane cu funcții mai înalte în statul român / Interviu Kovesi Episodul 2',
#   'video_date': '2026-05-19'},
#  {'video_id': 'xcPA6shtTqs',
#   'video_title': 'Turele, UGV-uri, prima Cobră: Ce au expus firmele de apărare din România la BSDA 2026 (II)',
#   'video_date': '2026-05-18'},
#  {'video_id': '8car9Ij3L8Q',
#   'video_title': 'Nicușor Dan, consultări cu partidele pentru un nou guvern / Declarațiile liderilor politici',
#   'video_date': '2026-05-18'},
#  {'video_id': 'XSUuceMKcI0',
#   'video_title': 'Laura Codruța Kovesi - șapte ani la vârful Parchetului European (Episodul 1)',
#   'video_date': '2026-05-18'},
#  {'video_id': '8yxOQrWHIVg',
#   'video_title': 'Alexandra Căpitănescu: „România a demonstrat că poate fi un popor unit, care își sprijină talentele”',
#   'video_date': '2026-05-17'},
#  {'video_id': 'd07jD97DIFE',
#   'video_title': 'Espresso, filtru sau capsule? Gadgeturi pentru cafea care chiar merită',
#   'video_date': '2026-05-16'},
#  {'video_id': 'cVSMZ_k3WYA',
#   'video_title': 'Ce au expus firmele de apărare din România la BSDA: Drone, barcă „de nescufundat” (I)',
#   'video_date': '2026-05-15'},
#  {'video_id': 'pAtK0qRA4fA',
#   'video_title': 'Cum oprești Meta să folosească postările tale pentru AI',
#   'video_date': '2026-05-14'},
#  {'video_id': 'QKo20YKhi_A',
#   'video_title': 'Grătarul începe cu organizarea',
#   'video_date': '2026-05-02'},
#  {'video_id': 'auEnrDy-FJ0',
#   'video_title': 'Alergarea &quot;La Petrovaselo în vie&quot;',
#   'video_date': '2026-04-26'}]

# %% [markdown]
# ## 6. Colectăm comentariile
# Pentru fiecare videoclip luăm comentariile publice ordonate după relevanță.
# În acest exercițiu nu folosim paginare, deci luăm maximum 100 comentarii per videoclip.

# %%
comments = []
for video in videos:
    print("Colectez:", video["video_title"][:80])
    comments_response = requests.get(
        f"{BASE_URL}/commentThreads",
        params={
            "part": "snippet",
            "videoId": video["video_id"],
            "maxResults": max_comments_per_video,
            "textFormat": "plainText",
            "order": "relevance",
            "key": API_KEY
        }
    )
    comments_data = comments_response.json()
    for comment_item in comments_data.get("items", []):
        snippet = comment_item["snippet"]["topLevelComment"]["snippet"]
        record = {
            "id": f"yt_{video['video_id']}_{comment_item['id']}",
            "source_platform": "youtube",
            "source_channel": handle,
            "text_raw": snippet["textDisplay"],
            "video_id": video["video_id"],
            "video_title": video["video_title"],
            "video_date": video["video_date"],
            "comment_date": snippet["publishedAt"][:10],
            "likes": snippet["likeCount"],
            "collected_at": datetime.utcnow().strftime("%Y-%m-%d")
        }
        comments.append(record)
len(comments)
# Out:
# Colectez: Investigăm persoane cu funcții mai înalte în statul român / Interviu Kovesi Epis
# C:\Users\diana\AppData\Local\Temp\ipykernel_20860\3206550858.py:28: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "collected_at": datetime.utcnow().strftime("%Y-%m-%d")
# Colectez: Turele, UGV-uri, prima Cobră: Ce au expus firmele de apărare din România la BSDA
# Colectez: Nicușor Dan, consultări cu partidele pentru un nou guvern / Declarațiile lideril
# Colectez: Laura Codruța Kovesi - șapte ani la vârful Parchetului European (Episodul 1)
# Colectez: Alexandra Căpitănescu: „România a demonstrat că poate fi un popor unit, care își
# Colectez: Espresso, filtru sau capsule? Gadgeturi pentru cafea care chiar merită
# Colectez: Ce au expus firmele de apărare din România la BSDA: Drone, barcă „de nescufundat
# Colectez: Cum oprești Meta să folosească postările tale pentru AI
# Colectez: Grătarul începe cu organizarea
# Colectez: Alergarea &quot;La Petrovaselo în vie&quot;
# 52

# %% [markdown]
# # Explorare si curatare

# %% [markdown]
# ## 7. Inspectăm primele comentarii
# Înainte să salvăm fișierul, verificăm dacă datele arată cum trebuie.

# %%
comments[:3]
# Out:
# [{'id': 'yt_p8Mw2mAtrQo_UgyPYxeqTiCBSZjixKV4AaABAg',
#   'source_platform': 'youtube',
#   'source_channel': 'g4media479',
#   'text_raw': 'Multa sanatate,doamna!',
#   'video_id': 'p8Mw2mAtrQo',
#   'video_title': 'Investigăm persoane cu funcții mai înalte în statul român / Interviu Kovesi Episodul 2',
#   'video_date': '2026-05-19',
#   'comment_date': '2026-05-19',
#   'likes': 9,
#   'collected_at': '2026-05-19'},
#  {'id': 'yt_p8Mw2mAtrQo_UgwCOUpAlR-P5v_3gWt4AaABAg',
#   'source_platform': 'youtube',
#   'source_channel': 'g4media479',
#   'text_raw': 'Multumim si felicitari pentru reportaj!',
#   'video_id': 'p8Mw2mAtrQo',
#   'video_title': 'Investigăm persoane cu funcții mai înalte în statul român / Interviu Kovesi Episodul 2',
#   'video_date': '2026-05-19',
#   'comment_date': '2026-05-19',
#   'likes': 10,
#   'collected_at': '2026-05-19'},
#  {'id': 'yt_p8Mw2mAtrQo_UgwOFDo29V8Nyv-lG154AaABAg',
#   'source_platform': 'youtube',
#   'source_channel': 'g4media479',
#   'text_raw': 'daca politicul sau institutiile de stat au ceva cu tine inseamna ca faci bine ceea ce faci',
#   'video_id': 'p8Mw2mAtrQo',
#   'video_title': 'Investigăm persoane cu funcții mai înalte în statul român / Interviu Kovesi Episodul 2',
#   'video_date': '2026-05-19',
#   'comment_date': '2026-05-19',
#   'likes': 2,
#   'collected_at': '2026-05-19'}]

# %%
comments[0].keys()
# Out:
# dict_keys(['id', 'source_platform', 'source_channel', 'text_raw', 'video_id', 'video_title', 'video_date', 'comment_date', 'likes', 'collected_at'])

# %% [markdown]
# ## 8. Curățare minimă a textului
# Acum pornim de la `text_raw` și construim o variantă curățată în câmpul `text`.
# Nu schimbăm sensul comentariului. Eliminăm doar zgomot simplu: linkuri, spații inutile, texte prea scurte și duplicate.

# %%
import re

def clean_text(text):
    text = re.sub(r"http\S+", "", text)      # elimină linkuri
    text = re.sub(r"\s+", " ", text)         # normalizează spațiile
    return text.strip()

# %% [markdown]
# ## 9. Aplicăm curățarea
# Pentru fiecare comentariu păstrăm textul original în `text_raw` și adăugăm textul curățat în `text`.

# %%
for comment in comments:
    comment["text"] = clean_text(comment["text_raw"])

comments[0]
# Out:
# {'id': 'yt_p8Mw2mAtrQo_UgyPYxeqTiCBSZjixKV4AaABAg',
#  'source_platform': 'youtube',
#  'source_channel': 'g4media479',
#  'text_raw': 'Multa sanatate,doamna!',
#  'video_id': 'p8Mw2mAtrQo',
#  'video_title': 'Investigăm persoane cu funcții mai înalte în statul român / Interviu Kovesi Episodul 2',
#  'video_date': '2026-05-19',
#  'comment_date': '2026-05-19',
#  'likes': 9,
#  'collected_at': '2026-05-19',
#  'text': 'Multa sanatate,doamna!'}

# %% [markdown]
# ## 10. Filtrăm comentariile prea scurte
# Pentru exercițiu păstrăm doar comentariile care au cel puțin 60 de caractere.
# Comentariile foarte scurte sunt greu de interpretat în analiza discursivă.

# %%
MIN_CHARS = 60

comments_clean = [
    comment for comment in comments
    if len(comment["text"]) >= MIN_CHARS
]

print("Comentarii brute:", len(comments))
print("Comentarii după filtrarea lungimii:", len(comments_clean))
# Out:
# Comentarii brute: 52
# Comentarii după filtrarea lungimii: 30

# %% [markdown]
# ## 11. Filtrăm textele cu prea puține litere
# Comentariile formate mai ales din emoji, simboluri sau caractere izolate produc zgomot.
# Păstrăm comentariile în care cel puțin 50% dintre caractere sunt litere.

# %%
MIN_ALPHA = 0.5

def alpha_ratio(text):
    if len(text) == 0:
        return 0
    letters = sum(char.isalpha() for char in text)
    return letters / len(text)

comments_clean = [
    comment for comment in comments_clean
    if alpha_ratio(comment["text"]) >= MIN_ALPHA
]

print("Comentarii după filtrarea literelor:", len(comments_clean))
# Out:
# Comentarii după filtrarea literelor: 30

# %% [markdown]
# ## 12. Eliminăm duplicatele
# Dacă același text apare de mai multe ori, îl păstrăm o singură dată.

# %%
seen_texts = set()
unique_comments = []

for comment in comments_clean:
    text = comment["text"].lower()
    if text not in seen_texts:
        unique_comments.append(comment)
        seen_texts.add(text)

comments_clean = unique_comments

print("Comentarii finale după deduplicare:", len(comments_clean))
# Out:
# Comentarii finale după deduplicare: 30

# %% [markdown]
# ## 14. Salvăm fișierul curățat
# Salvăm rezultatul în `data/cleaned/`.

# %%
clean_output_file = ROOT / "data" / "cleaned" / f"{student_id}_youtube_clean.jsonl"
clean_output_file.parent.mkdir(parents=True, exist_ok=True)

with clean_output_file.open("w", encoding="utf-8") as f:
    for comment in comments_clean:
        f.write(json.dumps(comment, ensure_ascii=False) + "\n")

with output_file.open("w", encoding="utf-8") as f:
    for comment in comments:
        f.write(json.dumps(comment, ensure_ascii=False) + "\n")

print("Comentarii brute salvate:", len(comments))
print("Comentarii curate salvate:", len(comments_clean))
print("Fișier:", clean_output_file)
# Out:
# Comentarii brute salvate: 52
# Comentarii curate salvate: 30
# Fișier: c:\Users\diana\Desktop\18.Ingineria_AI\echochamber-project-team3\data\cleaned\student_05_youtube_clean.jsonl

# %% [markdown]
# # Functia de curatare

# %%
import re

def clean_comments(comments, min_chars=60, min_alpha=0.5):
    cleaned = []
    seen_texts = set()
    
    for comment in comments:
        # 1. Curățare text
        text = comment["text_raw"]
        text = re.sub(r"http\S+", "", text)
        text = re.sub(r"\s+", " ", text).strip()
        
        # 2. Filtru lungime
        if len(text) < min_chars:
            continue
        
        # 3. Filtru proporție litere
        letters = sum(char.isalpha() for char in text)
        alpha_ratio = letters / len(text) if len(text) > 0 else 0
        
        if alpha_ratio < min_alpha:
            continue
        
        # 4. Filtru duplicate
        text_key = text.lower()
        if text_key in seen_texts:
            continue
        
        seen_texts.add(text_key)
        
        # 5. Păstrăm comentariul și adăugăm textul curățat
        new_comment = comment.copy()
        new_comment["text"] = text
        new_comment["lang"] = "ro"
        cleaned.append(new_comment)
    
    return cleaned

# %%
comments_clean = clean_comments(
    comments,
    min_chars=60,
    min_alpha=0.5
)

print("Comentarii brute:", len(comments))
print("Comentarii curate:", len(comments_clean))
# Out:
# Comentarii brute: 52
# Comentarii curate: 30

# %%
for comment in comments_clean[:3]:
    print("RAW:", comment["text_raw"])
    print("CLEAN:", comment["text"])
    print("---")
# Out:
# RAW: daca politicul sau institutiile de stat au ceva cu tine inseamna ca faci bine ceea ce faci
# CLEAN: daca politicul sau institutiile de stat au ceva cu tine inseamna ca faci bine ceea ce faci
# ---
# RAW: Mult succes Doamna Procuror Codruța Keovesi ❤❤❤.din Spania Barcelona...
# CLEAN: Mult succes Doamna Procuror Codruța Keovesi ❤❤❤.din Spania Barcelona...
# ---
# RAW: Bravo doamnå . Felicitări pentru munca depusă.
# Atingeți -vå de interne, parlament, desigur sunt destui implicați în asta .
# CLEAN: Bravo doamnå . Felicitări pentru munca depusă. Atingeți -vå de interne, parlament, desigur sunt destui implicați în asta .
# ---

# %%
clean_output_file = ROOT / "data" / "cleaned" / f"{student_id}_youtube_clean.jsonl"
clean_output_file.parent.mkdir(parents=True, exist_ok=True)

with clean_output_file.open("w", encoding="utf-8") as f:
    for comment in comments_clean:
        f.write(json.dumps(comment, ensure_ascii=False) + "\n")

print("Fișier salvat:", clean_output_file)
print("Comentarii salvate:", len(comments_clean))
# Out:
# Fișier salvat: c:\Users\diana\Desktop\18.Ingineria_AI\echochamber-project-team3\data\cleaned\student_05_youtube_clean.jsonl
# Comentarii salvate: 30

# %% [markdown]
# 15. Ce am obținut
# Am produs două fișiere:
# - `data/raw/student_XX_youtube_raw.jsonl` — comentarii brute
# - `data/cleaned/student_XX_youtube_clean.jsonl` — comentarii curățate
# Fișierul curățat va putea fi unit cu fișierele celorlalți membri ai echipei.
